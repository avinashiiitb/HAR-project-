# %%
import tensorflow as tf
# tf.enable_eager_execution()
import os
import itertools
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# from hilbert import hilbertCurve
import imgaug.augmenters as iaa
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow.keras import models,layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten,Activation,BatchNormalization
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tqdm import tqdm
from skimage.transform import rotate,rescale
from skimage.util import random_noise
from skimage.filters import gaussian
from scipy import ndimage
import numpy as np
import sklearn
import seaborn as sns
import nbformat
import plotly.express as px

# %%
import typing
import tensorflow_addons as tfa

# %%
tf.__version__,os.path.join('artifacts','raw_images')
# Out:
# ('2.10.0', 'artifacts\\raw_images')

# %%
label = ['05' ,  '06' , '07' , '08' , '09' , '10' , '11' ,'16' , '17' , '18' , '19']
dirname1 = []
filename1 = []
fullpath = []
for dirname, _, filenames in os.walk('C:/Users/avina/Downloads/77'):
    for filename in filenames:
        dirname1.append((dirname))
        filename1.append(filename)
        fullpath.append((os.path.join(dirname, filename)))

            
df = pd.DataFrame(columns=['path' , 'label' ])
label_1 = []
path = []
def create_dataframe(fullpath,label):
    for i in range(len(fullpath)):
        for j in range(len(label)):
            if (fullpath[i].split('\\')[4][29:31]== label[j]):
                path.append(fullpath[i])
                label_1.append(label[j])
    
           
    return path,label_1  

path,label_1=create_dataframe(fullpath,label)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2276\3283504141.py in <module>
#      23     return path,label_1
#      24
# ---> 25 path,label_1=create_dataframe(fullpath,label)
#
# ~\AppData\Local\Temp\ipykernel_2276\3283504141.py in create_dataframe(fullpath, label)
#      16     for i in range(len(fullpath)):
#      17         for j in range(len(label)):
# ---> 18             if (fullpath[i].split('\\')[4][29:31]== label[j]):
#      19                 path.append(fullpath[i])
#      20                 label_1.append(label[j])
#
# IndexError: list index out of range

# %%
fullpath[0]
# Out:
# 'C:/Users/avina/Downloads/77\\activity_spectogram_77GHz\\05_Walking_towards_radar\\04000000_1574696114_Raw_0.png'

# %%
fullpath='C:\\Users\\avina\\HAR_END_TO_END\\artifacts\\train_images\\0_05.jpg'

# %%
fullpath.split('\\')[6][-6:-4]
# Out:
# '05'

# %%
os.makedirs((os.path.join('C:\\Users\\avina\\HAR_END_TO_END\\artifacts1','train_images')),exist_ok=True)

# %%
path = df['path'].iloc[0]
l = df['classvalue'].iloc[0] 
image = cv2.imread(path)
path =os.path.join('artifacts','raw_images')
cv2.imwrite(os.path.join(path , l+'.jpg'),image)
# Out:
# True

# %%
for i in range(0,648):

# %%
df['classvalue'].iloc[0]
# Out:
# '00'

# %%
label = ['05' ,  '06' , '07' , '08' , '09' , '10' , '11' ,'16' , '17' , '18' , '19']

dirname1 = []
filename1 = []
fullpath = []
for dirname, _, filenames in os.walk("C:/Users/avina/Downloads/77"):
    for filename in filenames:
        dirname1.append((dirname))
        filename1.append(filename)
        fullpath.append((os.path.join(dirname, filename)))


df = pd.DataFrame(columns=['path' , 'label' ])
label1 = []
path = []
def create_dataframe(fullpath,label):
            
    for i in range(len(fullpath)):
        for j in range(len(label)):
            if (fullpath[i].split('/')[4][29:31]== label[j]):
                path.append(fullpath[i])
                label1.append(label[j])
    
           
    return path,label1  

path,label2=create_dataframe(fullpath,label)
df['path'] = path
df['label'] = label2
final = pd.DataFrame(df)
final.iloc[638]
# Out:
# path     C:/Users/avina/Downloads/77\activity_spectogra...
# label                                                   19
# Name: 638, dtype: object

# %%
labelname = []
classvalue = []

for i in range(len(df)):
    for j in range(len(label)):
        if (df['label'][i] ==  label[j]):
            if (label[j] == '05'):
                labelname.append('Walkingtowards')
                classvalue.append('00')
            elif (label[j] =='06'):
                labelname.append('walkingaway')
                classvalue.append('01')
            elif (label[j] =='07'):
                labelname.append('pickingobject')
                classvalue.append('02')
            elif (label[j] =='08'):
                labelname.append('bending')
                classvalue.append('03')
            elif (label[j] =='09'):
                labelname.append('sitting')
                classvalue.append('04')
            elif (label[j] =='10'):
                labelname.append('kneeling')
                classvalue.append('05')
            elif (label[j] =='11'):
                labelname.append('crawling')
                classvalue.append('06')
            elif (label[j] =='16'):
                labelname.append('walkingontoes')
                classvalue.append('07')
            elif (label[j] =='17'):
                labelname.append('limping')
                classvalue.append('08')
            elif (label[j] =='18'):
                labelname.append('shortsteps')
                classvalue.append('09')
            else :
                labelname.append('scissorsgait')
                classvalue.append('10')

df['labelname'] = labelname
df['classvalue'] = classvalue



for i in range(len(df)-1):
    path = df['path'].iloc[i]
    if(path == 'C:/Users/avina/Downloads/77\\activity_spectogram_77GHz\\08_bending\\activity_spectogram_77GHz - Shortcut.lnk'):
        df.drop(index = i,axis =0,inplace = True)
        print('del')
# Out:
# del

# %%
df['classvalue']
# Out:
# 0      00
# 1      00
# 2      00
# 3      00
# 4      00
#        ..
# 644    10
# 645    10
# 646    10
# 647    10
# 648    10
# Name: classvalue, Length: 648, dtype: object

# %%
y_train = df['classvalue']
y_train
y_train = y_train.to_numpy()

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(df,y_train, test_size = 0.20 , shuffle = True,random_state = 42,stratify=y_train)

# %%
fig = px.histogram(x_test, x=y_test)
fig.show()

# %%
def create_data(x_train,y_train):
    listimage = []
    
    for i in range(len(x_train)):
        path = x_train['path'].iloc[i]

        image = cv2.imread(path)
        image = cv2.resize(image,(128,128),interpolation=cv2.INTER_AREA)
        #image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) 
     
        listimage.append(image)
       
            
    
    return  listimage

x_train_resize = create_data(x_train,y_train)

x_train_resize_1 = np.array(x_train_resize)


len(x_train_resize_1)

x_test_resize = create_data(x_test,y_test)

x_test_resize_1 = np.array(x_test_resize)

# %%
iaa.GaussianBlur

# %%
aug1 = iaa.GaussianBlur(sigma = (0,1))
aug10 = iaa.AdditiveGaussianNoise(loc = 0 , scale = (0,1) , per_channel= True )
aug2 = iaa.Emboss(alpha = (1), strength = 1.5)
aug3 = iaa.Sharpen(alpha = (1.0) , lightness = (1.5))
aug4 = iaa.Crop(px=(0, 16))
#aug5 = iaa.ShearX((-20, 20))
aug6 = iaa.ImpulseNoise(0.1)
#aug7 = iaa.ScaleX((0.5, 1.5))
aug8 = iaa.LinearContrast((0.4, 1.6))
#aug9 = iaa.Solarize(0.5, threshold=(32, 128))

# %%
def augment(data,data1):
    aug_X_train = []
    aug_y_train = []
    for i  in range(len(data)):
        aug_X_train.append(data[i])
        
        aug_X_train.append(aug1.augment_image(data[i]))
        aug_X_train.append(aug10.augment_image(data[i]))
        aug_X_train.append(aug3.augment_image(data[i]))
       
        aug_X_train.append(aug6.augment_image(data[i]))
        
        
        for j in range(5):
            aug_y_train.append(data1[i])


    return   aug_X_train,aug_y_train


x_train_aug,aug_y_train = augment(x_train_resize_1,y_train)
len(x_train_aug),len(aug_y_train),type(x_train_aug), type(aug_y_train)
x_train_aug_2 = np.array(x_train_aug,dtype = 'float32')

aug_y_train_1 = np.array(aug_y_train ,dtype ='float32')
y_test = np.array(y_test ,dtype ='float32')

# %%
str(0)+'_'+str(aug_y_train_1[0])+'.jpg'
# Out:
# '0_5.0.jpg'

# %%
str(aug_y_train_1[8])
# Out:
# '2.0'

# %%
def normalization(train,test):
    mean = np.mean(train)
    std = np.mean(test)
    train = (train - mean)/std
    test = (test -mean)/std
    return train,test

# %%
x_train,x_test = normalization(x_train_aug_2,x_test_resize_1)

# %%
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow((x_train[i]))

plt.show()


for i in range(15):
  plt.subplot(5,5,i+1)
  plt.imshow(x_test[i])

plt.show()

# %%
x_train.shape , np.mean(x_train), np.mean(x_test) , np.var(x_train) , np.var(x_test)

# %%
y_train.shape

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 10

def activation_block(x):
    return layers.BatchNormalization()(layers.Activation("relu")(x))


def conv_stem(x, filters:int, patch_size:int):
    x = layers.Conv2D(filters,kernel_size = patch_size, strides = patch_size)(x)
    return activation_block(x)


def conv_mixer_block(x,filters:int,kernel_size:int):
    x0=x
    x = layers.DepthwiseConv2D(kernel_size = kernel_size , padding ='same')(x)
    #x = layers.Dropout(0.5)(x)
    x = layers.Add()([activation_block(x),x0])
    
    x = layers.Conv2D(filters, kernel_size =1)(x)
    x=activation_block(x)
    return x


def get_conv_mixer_256_8(image_size =72,filters =128 , depth=2,kernel_size =5,patch_size=2,num_classes=11):
    inputs = keras.Input((128,128,3))
    x = conv_stem(inputs,filters,patch_size)
    for _ in range(depth):
        x = conv_mixer_block(x,filters,kernel_size)
    x = layers.GlobalAvgPool2D()(x)
    #x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)


conv_mixer_model = get_conv_mixer_256_8()
conv_mixer_model.summary()

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle=True)
batch_size = 64
no_epochs = 50
verbosity = 1

fold_no = 1
i =1
acc_hist = []
hist_hist = []
acc_per_fold = []
loss_per_fold = []
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
callbacks = [ModelCheckpoint('C:/Users/avina/HAR_END_TO_END./model_128_Tesnorboard_STRATIFY_{epoch:4d}_val_accuracy{val_accuracy:.5f}_val_loss{val_loss:.5f}.h5', save_best_only=True, mode = 'max',  monitor='val_accuracy' )]

# %%
from datetime import datetime
logdir = "C:\\Users\\avina\\HAR_END_TO_END\\" + datetime.now().strftime("%Y%m%d-%H%M%S")
# Creates a file writer for the log directory.
file_writer = tf.summary.create_file_writer(logdir)
with file_writer.as_default():
  # Don't forget to reshape.
  images = x_test[:25]
  tf.summary.image("25 training data examples", images, max_outputs=25, step=0)


#%tensorboard --logdir C:\\Users\\avina\\HAR_END_TO_END

# %%
class_labels = ["Walkingtowards","walkingaway","pickingobject","bending","sitting","kneeling","crawling","walkingontoes","limping","shortsteps", "scissorsgait"]

# %%
# Clear out prior logging data.
from datetime import datetime
import io
logdir = "C:\\Users\\avina\\HAR_END_TO_END\\" + datetime.now().strftime("%Y%m%d-%H%M%S")
#file_writer = tf.summary.create_file_writer(logdir)

def plot_to_image(figure):
  """Converts the matplotlib plot specified by 'figure' to a PNG image and
  returns it. The supplied figure is closed and inaccessible after this call."""
  # Save the plot to a PNG in memory.
  buf = io.BytesIO()
  plt.savefig(buf, format='png')
  # Closing the figure prevents it from being displayed directly inside
  # the notebook.
  plt.close(figure)
  buf.seek(0)
  # Convert PNG buffer to TF image
  image = tf.image.decode_png(buf.getvalue(), channels=4)
  # Add the batch dimension
  image = tf.expand_dims(image, 0)
  return image

# %%
def plot_confusion_matrix(cm, class_names):
  """
  Returns a matplotlib figure containing the plotted confusion matrix.

  Args:
    cm (array, shape = [n, n]): a confusion matrix of integer classes
    class_names (array, shape = [n]): String names of the integer classes
  """
  figure = plt.figure(figsize=(8, 8))
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title("Confusion matrix")
  plt.colorbar()
  tick_marks = np.arange(len(class_names))
  plt.xticks(tick_marks, class_names, rotation=45)
  plt.yticks(tick_marks, class_names)

  # Compute the labels from the normalized confusion matrix.
  labels = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

  # Use white text if squares are dark; otherwise black.
  threshold = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    color = "white" if cm[i, j] > threshold else "black"
    plt.text(j, i, labels[i, j], horizontalalignment="center", color=color)

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  return figure

# %%
from datetime import datetime
logdir = "C:\\Users\\avina\\HAR_END_TO_END\\" + datetime.now().strftime("%Y%m%d-%H%M%S")
# Define the basic TensorBoard callback.
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir,histogram_freq=1,write_images=True,profile_batch=(10,20))
file_writer_cm = tf.summary.create_file_writer(logdir + '/cm')

# %%
def log_confusion_matrix(epoch, logs):
  # Use the model to predict the values from the validation dataset.
  test_pred_raw = conv_mixer_model.predict(x_test)
  test_pred = np.argmax(test_pred_raw, axis=1)

  # Calculate the confusion matrix.
  cm = sklearn.metrics.confusion_matrix(y_test, test_pred)
  # Log the confusion matrix as an image summary.
  figure = plot_confusion_matrix(cm, class_names=class_labels)
  cm_image = plot_to_image(figure)

  # Log the confusion matrix as an image summary.
  with file_writer_cm.as_default():
    tf.summary.image("epoch_confusion_matrix", cm_image, step=epoch)

# Define the per-epoch callback.
cm_callback = keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

# %%
conv_mixer_model.compile(
        optimizer = keras.optimizers.Adam(lr=1e-03, decay=1e-6),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

# %%
# %load_ext tensorboard
# %tensorboard --logdir C:\\Users\\avina\\HAR_END_TO_END
# Train the classifier.
conv_mixer_model.fit(
    x_train,
    aug_y_train_1,
    epochs=4,
    verbose=1, # Suppress chatty output
    callbacks=[tensorboard_callback, cm_callback],
    validation_data=(x_test,y_test),
)

# %%
import gzip

with gzip.open('C:\\Users\\avina\\HAR_END_TO_END\\20230405-172814\\plugins\\profile\\2023_04_05_11_58_36\\CIET.memory_profile.json.gz','rt') as fin:        
    for line in fin:        
        lines = line.split(' ')

        for l in lines:
            print(l)
# Out:
# {"memoryProfilePerAllocator":{"\u0000pu_host_bfc":{"memoryProfileSnapshots":[],"profileSummary":{"peakBytesUsageLifetime":"8391936","peakStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391936","freeMemoryBytes":"68711084800","fragmentation":0,"peakBytesInUse":"8391936"},"peakStatsTimePs":"1097481162000","memoryCapacity":"68719476736"},"activeAllocations":[{"snapshotIndex":"-1","specialIndex":"0","numOccurrences":"1"}],"specialAllocations":[{"memoryActivity":"ALLOCATION","requestedBytes":"8391936","allocationBytes":"8391936","address":"0","tfOpName":"unused
# preallocated
# device
# memory","stepId":"11","regionType":"persist/dynamic","dataType":"INVALID","tensorShape":"unknown"}],"sampledTimelineSnapshots":[{"timeOffsetPs":"2468932000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3328","freeMemoryBytes":"68719473408","fragmentation":0.199746,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"128","allocationBytes":"256","address":"21552434176","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"float","tensorShape":"\u000032]"}},{"timeOffsetPs":"2484233000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391936","freeMemoryBytes":"68711084800","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"6291456","allocationBytes":"8388608","address":"21554528256","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"float","tensorShape":"\u000032"}},{"timeOffsetPs":"2581557000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391680","freeMemoryBytes":"68711085056","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"128","allocationBytes":"256","address":"21552434176","tfOpName":"SameWorkerRecvDone","stepId":"1","regionType":"dynamic","dataType":"float","tensorShape":"\u000032]"}},{"timeOffsetPs":"2771342000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391936","freeMemoryBytes":"68711084800","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434176","tfOpName":"strided_slice","stepId":"0","regionType":"output","dataType":"int32","tensorShape":"\u0000]"}},{"timeOffsetPs":"3066415000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391680","freeMemoryBytes":"68711085056","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434176","tfOpName":"strided_slice","stepId":"1","regionType":"output","dataType":"int32","tensorShape":"\u0000]"}},{"timeOffsetPs":"4433023000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3072","freeMemoryBytes":"68719473664","fragmentation":0.199766,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"6291456","allocationBytes":"8388608","address":"21554528256","tfOpName":"SameWorkerRecvDone","stepId":"1","regionType":"dynamic","dataType":"float","tensorShape":"\u000032"}},{"timeOffsetPs":"6007162000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3328","freeMemoryBytes":"68719473408","fragmentation":0.199746,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"16","allocationBytes":"256","address":"21552434176","tfOpName":"gradient_tape/model/global_average_pooling2d/Shape","stepId":"0","regionType":"output","dataType":"int32","tensorShape":"\u00004]"}},{"timeOffsetPs":"6181650000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3584","freeMemoryBytes":"68719473152","fragmentation":0.199726,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434432","tfOpName":"gradient_tape/model/global_average_pooling2d/floordiv","stepId":"0","regionType":"output","dataType":"int32","tensorShape":"\u0000]"}},{"timeOffsetPs":"6500893000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3840","freeMemoryBytes":"68719472896","fragmentation":0.199707,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434688","tfOpName":"sparse_categorical_crossentropy/weighted_loss/num_elements","stepId":"0","regionType":"output","dataType":"int32","tensorShape" ...
# preallocated
# device
# memory","stepId":"10","regionType":"persist/dynamic","dataType":"INVALID","tensorShape":"unknown"}],"sampledTimelineSnapshots":[{"timeOffsetPs":"2367080000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"509826560","freeMemoryBytes":"1245397915","fragmentation":0.0639931,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"128","allocationBytes":"256","address":"8782883072","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"float","tensorShape":"\u000032]"}},{"timeOffsetPs":"2441971000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516118272","freeMemoryBytes":"1239106203","fragmentation":0.0592404,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"8782879488","tfOpName":"Adam/Cast_1","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"2628291000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516118784","freeMemoryBytes":"1239105691","fragmentation":0.05924,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"8782894080","tfOpName":"Adam/Cast_3","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"2686571000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516118784","freeMemoryBytes":"1239105691","fragmentation":0.05924,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"8782876928","tfOpName":"Adam/Pow","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"2871070000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516119296","freeMemoryBytes":"1239105179","fragmentation":0.0592397,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"9292697856","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"int32","tensorShape":"\u0000]"}},{"timeOffsetPs":"3114147000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516119552","freeMemoryBytes":"1239104923","fragmentation":0.0592395,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"9292698112","tfOpName":"Cast","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"4549177000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"595813632","freeMemoryBytes":"1159410843","fragmentation":1.10401e-06,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"6291456","allocationBytes":"6291456","address":"9372396032","tfOpName":"model/activation/Relu","stepId":"0","regionType":"temp","dataType":"float","tensorShape":"\u000032"}},{"timeOffsetPs":"4961897000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"662928640","freeMemoryBytes":"1092295835","fragmentation":1.17184e-06,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"67108864","allocationBytes":"67108864","address":"9378693632","tfOpName":"model/activation/Relu","stepId":"0","regionType":"temp","dataType":"float","tensorShape":"\u000032"}},{"timeOffsetPs":"5148919000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"595819776","freeMemoryBytes":"1159404699","fragmentation":1.10401e-06,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"67108864","allocationBytes":"67108864","address":"9378693632","tfOpName":"model/activation/Relu","stepId":"0","regionType":"temp","dataType":"float","tensorShape":"\u000032"}},{"timeOffsetPs":"5180368000","aggregationStats":{"stack ...

# %%
line.split(' ')
# Out:
# ['{"memoryProfilePerAllocator":{"\\u0000pu_host_bfc":{"memoryProfileSnapshots":[],"profileSummary":{"peakBytesUsageLifetime":"8391936","peakStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391936","freeMemoryBytes":"68711084800","fragmentation":0,"peakBytesInUse":"8391936"},"peakStatsTimePs":"1097481162000","memoryCapacity":"68719476736"},"activeAllocations":[{"snapshotIndex":"-1","specialIndex":"0","numOccurrences":"1"}],"specialAllocations":[{"memoryActivity":"ALLOCATION","requestedBytes":"8391936","allocationBytes":"8391936","address":"0","tfOpName":"unused',
#  'preallocated',
#  'device',
#  'memory","stepId":"11","regionType":"persist/dynamic","dataType":"INVALID","tensorShape":"unknown"}],"sampledTimelineSnapshots":[{"timeOffsetPs":"2468932000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3328","freeMemoryBytes":"68719473408","fragmentation":0.199746,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"128","allocationBytes":"256","address":"21552434176","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"float","tensorShape":"\\u000032]"}},{"timeOffsetPs":"2484233000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391936","freeMemoryBytes":"68711084800","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"6291456","allocationBytes":"8388608","address":"21554528256","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"float","tensorShape":"\\u000032"}},{"timeOffsetPs":"2581557000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391680","freeMemoryBytes":"68711085056","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"128","allocationBytes":"256","address":"21552434176","tfOpName":"SameWorkerRecvDone","stepId":"1","regionType":"dynamic","dataType":"float","tensorShape":"\\u000032]"}},{"timeOffsetPs":"2771342000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391936","freeMemoryBytes":"68711084800","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434176","tfOpName":"strided_slice","stepId":"0","regionType":"output","dataType":"int32","tensorShape":"\\u0000]"}},{"timeOffsetPs":"3066415000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"8391680","freeMemoryBytes":"68711085056","fragmentation":0,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434176","tfOpName":"strided_slice","stepId":"1","regionType":"output","dataType":"int32","tensorShape":"\\u0000]"}},{"timeOffsetPs":"4433023000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3072","freeMemoryBytes":"68719473664","fragmentation":0.199766,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"6291456","allocationBytes":"8388608","address":"21554528256","tfOpName":"SameWorkerRecvDone","stepId":"1","regionType":"dynamic","dataType":"float","tensorShape":"\\u000032"}},{"timeOffsetPs":"6007162000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3328","freeMemoryBytes":"68719473408","fragmentation":0.199746,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"16","allocationBytes":"256","address":"21552434176","tfOpName":"gradient_tape/model/global_average_pooling2d/Shape","stepId":"0","regionType":"output","dataType":"int32","tensorShape":"\\u00004]"}},{"timeOffsetPs":"6181650000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3584","freeMemoryBytes":"68719473152","fragmentation":0.199726,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434432","tfOpName":"gradient_tape/model/global_average_pooling2d/floordiv","stepId":"0","regionType":"output","dataType":"int32","tensorShape":"\\u0000]"}},{"timeOffsetPs":"6500893000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"3840","freeMemoryBytes":"68719472896","fragmentation":0.199707,"peakBytesInUse":"8391936"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"21552434688","tfOpName":"sparse_categorical_crossentropy/weighted_loss/num_elements","stepId":"0","regionType":"output","dataType":"int32","te ...
#  'preallocated',
#  'device',
#  'memory","stepId":"10","regionType":"persist/dynamic","dataType":"INVALID","tensorShape":"unknown"}],"sampledTimelineSnapshots":[{"timeOffsetPs":"2367080000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"509826560","freeMemoryBytes":"1245397915","fragmentation":0.0639931,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"128","allocationBytes":"256","address":"8782883072","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"float","tensorShape":"\\u000032]"}},{"timeOffsetPs":"2441971000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516118272","freeMemoryBytes":"1239106203","fragmentation":0.0592404,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"8782879488","tfOpName":"Adam/Cast_1","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"2628291000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516118784","freeMemoryBytes":"1239105691","fragmentation":0.05924,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"8782894080","tfOpName":"Adam/Cast_3","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"2686571000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516118784","freeMemoryBytes":"1239105691","fragmentation":0.05924,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"8782876928","tfOpName":"Adam/Pow","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"2871070000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516119296","freeMemoryBytes":"1239105179","fragmentation":0.0592397,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"9292697856","tfOpName":"SameWorkerRecvDone","stepId":"0","regionType":"dynamic","dataType":"int32","tensorShape":"\\u0000]"}},{"timeOffsetPs":"3114147000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"516119552","freeMemoryBytes":"1239104923","fragmentation":0.0592395,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"4","allocationBytes":"256","address":"9292698112","tfOpName":"Cast","stepId":"0","regionType":"(null)","dataType":"INVALID","tensorShape":""}},{"timeOffsetPs":"4549177000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"595813632","freeMemoryBytes":"1159410843","fragmentation":1.10401e-06,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"6291456","allocationBytes":"6291456","address":"9372396032","tfOpName":"model/activation/Relu","stepId":"0","regionType":"temp","dataType":"float","tensorShape":"\\u000032"}},{"timeOffsetPs":"4961897000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"662928640","freeMemoryBytes":"1092295835","fragmentation":1.17184e-06,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"ALLOCATION","requestedBytes":"67108864","allocationBytes":"67108864","address":"9378693632","tfOpName":"model/activation/Relu","stepId":"0","regionType":"temp","dataType":"float","tensorShape":"\\u000032"}},{"timeOffsetPs":"5148919000","aggregationStats":{"stackReservedBytes":"0","heapAllocatedBytes":"595819776","freeMemoryBytes":"1159404699","fragmentation":1.10401e-06,"peakBytesInUse":"1461943040"},"activityMetadata":{"memoryActivity":"DEALLOCATION","requestedBytes":"67108864","allocationBytes":"67108864","address":"9378693632","tfOpName":"model/activation/Relu","stepId":"0","regionType":"temp","dataType":"float","tensorShape":"\\u000032"}},{"timeOffsetPs":"5180368000","aggregationStats": ...

# %%
import gzip

with gzip.open('C:\\Users\\avina\\HAR_END_TO_END\\20230405-172814\\plugins\\profile\\2023_04_05_11_58_36\\CIET.trace.json.gz','r') as fin:        
    for line in fin:        
        print('got line', line)
# Out:
# got line b'{"displayTimeUnit":"ns","metadata":{"highres-ticks":true},"traceEvents":[{"ph":"M","pid":1,"name":"process_name","args":{"name":"/device:GPU:0"}},{"ph":"M","pid":1,"name":"process_sort_index","args":{"sort_index":1}},{"ph":"M","pid":501,"name":"process_name","args":{"name":"/host:CPU"}},{"ph":"M","pid":501,"name":"process_sort_index","args":{"sort_index":501}},{"ph":"M","pid":501,"tid":3680,"name":"thread_name","args":{"name":"tf_data_private_threadpool"}},{"ph":"M","pid":501,"tid":3680,"name":"thread_sort_index","args":{"sort_index":11}},{"ph":"M","pid":501,"tid":6156,"name":"thread_name","args":{"name":"tf_Compute"}},{"ph":"M","pid":501,"tid":6156,"name":"thread_sort_index","args":{"sort_index":4}},{"ph":"M","pid":501,"tid":6592,"name":"thread_name","args":{"name":"tf_Compute"}},{"ph":"M","pid":501,"tid":6592,"name":"thread_sort_index","args":{"sort_index":3}},{"ph":"M","pid":501,"tid":14980,"name":"thread_name","args":{"name":"tf_Compute"}},{"ph":"M","pid":501,"tid":14980,"name":"thread_sort_index","args":{"sort_index":5}},{"ph":"M","pid":501,"tid":16300,"name":"thread_name","args":{"name":"tf_data_iterator_get_next"}},{"ph":"M","pid":501,"tid":16300,"name":"thread_sort_index","args":{"sort_index":8}},{"ph":"M","pid":501,"tid":16808,"name":"thread_name","args":{"name":"tf_data_iterator_resource"}},{"ph":"M","pid":501,"tid":16808,"name":"thread_sort_index","args":{"sort_index":9}},{"ph":"M","pid":501,"tid":16900,"name":"thread_name","args":{"name":"tf_Compute"}},{"ph":"M","pid":501,"tid":16900,"name":"thread_sort_index","args":{"sort_index":2}},{"ph":"M","pid":501,"tid":17808,"name":"thread_name","args":{"name":"tf_Device_Event_Manager"}},{"ph":"M","pid":501,"tid":17808,"name":"thread_sort_index","args":{"sort_index":7}},{"ph":"M","pid":501,"tid":18504,"name":"thread_name","args":{"name":"tf_data_private_threadpool"}},{"ph":"M","pid":501,"tid":18504,"name":"thread_sort_index","args":{"sort_index":10}},{"ph":"M","pid":501,"tid":21460,"name":"thread_name","args":{"name":"tf_Compute"}},{"ph":"M","pid":501,"tid":21460,"name":"thread_sort_index","args":{"sort_index":6}},{"ph":"M","pid":501,"tid":22372,"name":"thread_sort_index","args":{"sort_index":1}},{"ph":"X","pid":501,"tid":22372,"ts":875.73699999999997,"dur":53835.665999999997,"name":"train_function","args":{"tf_function_call":"notTraced-nonXla","tracing_count":"2"}},{"ph":"X","pid":501,"tid":22372,"ts":1291.3579999999999,"dur":52809.078999999998,"name":"TFE_Py_ExecuteCancelable"},{"ph":"X","pid":501,"tid":22372,"ts":1344.0070000000001,"dur":52752.942999999999,"name":"EagerExecute","args":{"eager_op":"__inference_train_function_2042","is_func":"1"}},{"ph":"X","pid":501,"tid":22372,"ts":1347.944,"dur":52747.493000000002,"name":"EagerLocalExecute: __inference_train_function_2042"},{"ph":"X","pid":501,"tid":22372,"ts":1349.0060000000001,"dur":108.134,"name":"EagerCopyToDevice"},{"ph":"X","pid":501,"tid":22372,"ts":1837.405,"dur":4.5579999999999998,"name":"ValidateInputTypeAndPlacement"},{"ph":"X","pid":501,"tid":22372,"ts":1843.9670000000001,"dur":52247.563000000002,"name":"EagerKernelExecute"},{"ph":"X","pid":501,"tid":22372,"ts":1849.547,"dur":52233.656999999999,"name":"KernelAndDeviceFunc::Run"},{"ph":"X","pid":501,"tid":22372,"ts":1895.2829999999999,"dur":20.748999999999999,"name":"FunctionRun","args":{"group_id":"0","id":"-1945960745552348430"}},{"ph":"X","pid":501,"tid":22372,"ts":1921.5930000000001,"dur":5.54,"name":"FunctionRun","args":{"group_id":"1","id":"-1945960745552348430"}},{"ph":"X","pid":501,"tid":22372,"ts":54752.370000000003,"dur":11.311999999999999,"name":"TFE_DeleteTensorHandle"},{"ph":"X","pid":501,"tid":22372,"ts":54766.086000000003,"dur":2.6349999999999998,"name":"TFE_DeleteTensorHandle"},{"ph":"X","pid":501,"tid":22372,"ts":139158.40299999999,"dur":256.46199999999999,"name":"TFE_Py_FastPathExecute_C"},{"ph":"X","pid":501,"tid":22372,"ts":139208.136,"dur":96.241,"name":"EagerExecute","args":{"eager_op":"","is_func":"0"}},{"ph":"X","pid":501,"t ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir C:\\Users\\avina\\HAR_END_TO_END
#tensorboard --logdir C:\\Users\\avina\\HAR_END_TO_END - type in the cmd below
#tensorboard --logdir C:\\Users\\avina\\HAR_END_TO_END --bind_all

#tensorboard --logdir C:\Users\avina\HAR_END_TO_END\20230405-133226 - write like this if you want visualization for 
# a particular folder
#C:\Users\avina\HAR_END_TO_END\20230405-133226\plugins\profile\2023_04_05_08_02_42
# Out:
#       <iframe id="tensorboard-frame-733336d50abf8ac9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-733336d50abf8ac9");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
tensorboard --logdir=C:\Users\avina\HAR_END_TO_END\20230405-133226\plugins --port=6006

# %%
# !C:\Users\avina\HAR_END_TO_END\20230405-133226\plugins\profile\\

# %%
# !pip3 freeze
